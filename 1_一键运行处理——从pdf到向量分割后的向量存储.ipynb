# %% [markdown]
# 一键运行处理 —— 从 pdf 到向量分割后的向量存储
#
# One-Click Processing — From PDF to Segmented Vector Storage
#
# 使用者可以不用顾及py的设计运行顺序，通过 build_demo.py 即可一键处理
#
# Users do not need to concern themselves with Python's design and execution order, and can complete processing with one click via build_demo.py.

# %%
from build_demo import build_demo

summary = build_demo(
    input_file=r"doc2x\doc2x_output\test\test.md",
    workspace=r"examples\test_case",
    llm_env=r"C:\Users\12279\ZHIPU.env",
    embedding_model=r"D:\BGE_large_en_1.5v",
    rerank_model=r"D:\BGE-rerank-large",
    device="cuda",
)

summary
# Out:
# [WARN] Markdown input has no sibling images directory: C:\Users\12279\MatSci_RAG\matsci_rag\doc2x\doc2x_output\test\images
#
# ...
# STEP 1: Markdown input (Doc2X stage skipped)
# ...
# [MD] C:\Users\12279\MatSci_RAG\matsci_rag\examples\test_case\source\test.md
#
# ...
# STEP 2: Markdown normalization
# ...
# [OK] C:\Users\12279\MatSci_RAG\matsci_rag\examples\test_case\intermediate\test.cleaned.md
#
# ...
# STEP 3: Markdown -> structured JSON
# ...
# [OK] C:\Users\12279\MatSci_RAG\matsci_rag\examples\test_case\intermediate\test.json
#
# ...
# STEP 4: Structured JSON -> evidence graph
# ...
# D:\anaconda\envs\pokemon\Lib\site-packages\spacy\language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]
# Token indices sequence length is longer than the specified maximum sequence length for this model (711 > 512). Running this sequence through the model will result in indexing errors
# [OK] Evidence graph built
# ...
